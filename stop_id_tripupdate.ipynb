# %%
import pandas as pd

df = pd.read_csv("data/rt_trips.csv")

# 1) On filtre d'abord pour la ligne 51
ligne_51 = df[df["route_id"] == "51"]

# 2) Parmi ces voyages, on prend un trip_id (le premier par exemple)
trip_id_51 = ligne_51["trip_id"].iloc[0]

# 3) On affiche toutes les mises à jour de ce trip
trip_51 = ligne_51[ligne_51["trip_id"] == trip_id_51]

print(trip_51[["trip_id", "route_id", "stop_id", "arrival_delay", "departure_delay"]])
# Out:
#                                               trip_id route_id  stop_id  \
# 0   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51     2832
# 1   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51      412
# 2   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51      602
# 3   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51     1269
# 4   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51      415
# 5   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51       34
# 6   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51     1109
# 7   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51     1126
# 8   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51     1098
# 9   6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51       83
# 10  6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51      930
# 11  6416310-51_R_99_5103_16:23-PROJET2025-51-Semai...       51      531
# ...
